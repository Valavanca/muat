# %%
# %cd ..
# Out:
# /data/valavanca/workdir/muat
# /data/valavanca/workdir/muat/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
file_path = 'release_28/Projects/LICA-FR/exp_seq.LICA-FR.tsv.gz'

# Read the TSV file
df = pd.read_csv(file_path, sep='\t', compression='gzip')
df.head()
# Out:
#   icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0       DO50875      LICA-FR         SP112352       SA529909
# 1       DO50875      LICA-FR         SP112352       SA529909
# 2       DO50875      LICA-FR         SP112352       SA529909
# 3       DO50875      LICA-FR         SP112352       SA529909
# 4       DO50875      LICA-FR         SP112352       SA529909
#
#   submitted_sample_id               analysis_id gene_model  \
# 0            CHC1600T  RNAseq_24032018_CHC1600T    Ensembl
# 1            CHC1600T  RNAseq_24032018_CHC1600T    Ensembl
# 2            CHC1600T  RNAseq_24032018_CHC1600T    Ensembl
# 3            CHC1600T  RNAseq_24032018_CHC1600T    Ensembl
# 4            CHC1600T  RNAseq_24032018_CHC1600T    Ensembl
#
#               gene_id  normalized_read_count  raw_read_count  ...  \
# 0  ENSG00000000003.10              28.511362            4369  ...
# 1   ENSG00000000005.5               0.460660               0  ...
# ...
